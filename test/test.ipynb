# %%
import pandas as pd
from hdfs.ext.kerberos import KerberosClient

hdfs_client = KerberosClient('http://localhost:9870/','OPTIONAL')
with hdfs_client.read('/data/vietnamnet/vietnamnet-29-01-2023.json') as reader:
    df = pd.read_json(reader)
    
df.head(10)
# Out:
#                                                title  \
# 0        Đêm không ngủ trước ngày ký Hiệp định Paris
# 1  Thủ tướng kiểm tra dự án cao tốc Nha Trang – C...
# 2  Giây phút xúc động của bà Nguyễn Thị Bình khi ...
# 3  Bí thư TP.HCM: Phải hành động để xứng đáng với...
# 4  Bắt chủ xe và tài xế gây tai nạn làm 3 người v...
# 5  Tổng Bí thư Nguyễn Phú Trọng: Cán bộ chủ chốt ...
# 6  Ngày vía Thần Tài: Lì xì mạ vàng, hũ muối, gạo...
# 7  Vụ bé trai 10 tuổi gặp nạn: Đã kéo ống trụ bê ...
# 8           Dự báo thời tiết 18/1: Miền Bắc rét cóng
# 9   Tài xế taxi đỡ đẻ thành công cho sản phụ trên xe
#
#                                              summary  \
# 0  VietNamNet giới thiệu những hồi ức của đồng ch...
# 1  Ngày 26/1 (mùng 5 Tết), Thủ tướng Phạm Minh Ch...
# 2  “Đặt bút ký vào bản Hiệp định Paris lịch sử rấ...
# 3  Triển vọng trong năm 2023 của TP.HCM là bứt ph...
# 4  VKSND huyện Mai Châu (Hòa Bình) đã phê chuẩn q...
# 5  Theo Tổng Bí thư Nguyễn Phú Trọng, cán bộ chủ ...
# ...
